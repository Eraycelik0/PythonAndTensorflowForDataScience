# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
npDizisi1 = np.linspace(0,10,20)
npDizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
npDizisi2 = npDizisi1**2

# %%
npDizisi2
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
(benimFigur, benimEksen) = pyt.subplots()
benimEksen.plot(npDizisi1, npDizisi2, "g", alpha=0.3)
benimEksen.plot(npDizisi2, npDizisi1, "b")

# %%
(yeniFigure, yeniEksen) = plt.subplots()
yeniEksen.plot(npDizisi1, npDizisi1 + 2, color="blue", linewidth=2.0 )
yeniEksen.plot(npDizisi1, npDizisi1 + 3, color="00000", linewidth=1.0,marker="o",markersize=4, markerfacecolor="red")

yeniEksen.plot(npDizisi1, npDizisi1+4, color="#C96F23", linestyle = ":" )

# %% [markdown]
# ## scatter

# %%
plt.scatter(npDizisi1,npDizisi2)

# %% [markdown]
# ## histogram

# %%
yeniDizi = np.random.randint(0,100,50)
yeniDizi
# Out:
# array([51, 39, 15, 55, 94, 38, 33, 62, 88,  1, 56, 24, 87, 79, 94, 42, 26,
#         0, 66, 19, 88, 29, 60, 80, 34, 30, 76, 11, 79, 29,  7, 15, 40,  5,
#        77, 25, 84, 38, 94, 31, 10, 62, 70, 62, 46, 12, 38, 79, 46, 36])

# %%
plt.hist(yeniDizi)
# Out:
# (array([4., 5., 4., 7., 8., 3., 4., 2., 7., 6.]),
#  array([ 0. ,  9.4, 18.8, 28.2, 37.6, 47. , 56.4, 65.8, 75.2, 84.6, 94. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## boxplot

# %%
plt.boxplot(yeniDizi*2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x214a1a83550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x214a1a83af0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x214a1a83280>],
#  'medians': [<matplotlib.lines.Line2D at 0x214a1a960d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x214a1a963a0>],
#  'means': []}
